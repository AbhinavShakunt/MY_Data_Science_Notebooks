# %%
 import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("/content/drive/MyDrive/telco.csv")
df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6970  8083-YTZES    Male              0      No         No       4
# 6083  1468-DEFNC    Male              1     Yes        Yes      64
# 1569  0799-DDIHE  Female              0     Yes        Yes      15
# 5721  6064-ZATLR  Female              0      No         No      27
# 169   1159-WFSGR  Female              0     Yes        Yes      16
# 6189  4718-WXBGI    Male              0     Yes        Yes      72
# 2696  5472-CVMDX  Female              0      No         No      68
# 483   5168-MQQCA  Female              0     Yes         No      72
# 3115  4822-NGOCH  Female              0      No         No      13
# 6180  0201-MIBOL  Female              1      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 6970          Yes               Yes     Fiber optic                   No  ...
# 6083          Yes               Yes              No  No internet service  ...
# 1569          Yes                No             DSL                   No  ...
# 5721          Yes                No             DSL                  Yes  ...
# 169           Yes                No              No  No internet service  ...
# 6189          Yes               Yes             DSL                  Yes  ...
# 2696           No  No phone service             DSL                  Yes  ...
# 483           Yes               Yes     Fiber optic                   No  ...
# 3115          Yes               Yes     Fiber optic                   No  ...
# 6180          Yes               Yes     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 6970                   No                   No                   No
# 6083  No internet service  No internet service  No internet service
# 1569                   No                   No                   No
# 5721                   No                   No                   No
# 169   No internet service  No internet service  No internet service
# 6189                  Yes                  Yes                  Yes
# 2696                  Yes                  Yes                   No
# 483                   Yes                  Yes                  Yes
# 3115                  Yes                   No                   No
# 6180                   No                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 6970                   No  Month-to-month              Yes
# 6083  No internet service        Two year              Yes
# 1569                   No  Month-to-month               No
# 5721                   No        Two year               No
# 169   No internet service  Month-to-month               No
# 6189                  Yes        Two year              Yes
# 2696                   No        Two year               No
# 483                   Yes        One year              Yes
# 3115                   No  Month-to-month              Yes
# 6180                  Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 6970           Electronic check          74.35        265.35   Yes
# 6083  Bank transfer (automatic)          24.40       1548.65    No
# 1569           Electronic check          46.30        639.45    No
# 5721  Bank transfer (automatic)          52.85       1498.65    No
# 169            Electronic check          20.40         321.4    No
# 6189    Credit card (automatic)          91.95        6614.9    No
# 2696               Mailed check          38.90        2719.2    No
# 483   Bank transfer (automatic)         108.50        8003.8    No
# 3115           Electronic check          84.45        1058.6   Yes
# 6180  Bank transfer (automatic)         102.40       6471.85    No
#
# [10 rows x 21 columns]

# %%
from matplotlib import pyplot as plt
_df_1['MonthlyCharges'].plot(kind='hist', bins=20, title='MonthlyCharges')
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bd7be42e6a53> in <cell line: 2>()
#       1 from matplotlib import pyplot as plt
# ----> 2 _df_1['MonthlyCharges'].plot(kind='hist', bins=20, title='MonthlyCharges')
#       3 plt.gca().spines[['top', 'right',]].set_visible(False)
#
# NameError: name '_df_1' is not defined

# %%
df.drop('customerID',axis='columns',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-8ad08ea1f911> in <cell line: 1>()
# ----> 1 df.drop('customerID',axis='columns',inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['customerID'] not found in axis"

# %%
df.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 82    Female              0     Yes         No       7          Yes
# 6482    Male              0      No         No       1          Yes
# 5248  Female              0     Yes         No      12          Yes
# 3714    Male              0     Yes        Yes      69          Yes
# 1233  Female              0     Yes        Yes      70          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 82              No     Fiber optic                   No                   No
# 6482           Yes     Fiber optic                   No                   No
# 5248            No              No  No internet service  No internet service
# 3714            No             DSL                  Yes                  Yes
# 1233           Yes              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 82                    Yes                   No                   No
# 6482                  Yes                   No                  Yes
# 5248  No internet service  No internet service  No internet service
# 3714                  Yes                   No                   No
# 1233  No internet service  No internet service  No internet service
#
#           StreamingMovies        Contract PaperlessBilling  \
# 82                     No  Month-to-month              Yes
# 6482                  Yes  Month-to-month              Yes
# 5248  No internet service        Two year              Yes
# 3714                   No        Two year              Yes
# 1233  No internet service        Two year               No
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 82    Bank transfer (automatic)           75.15        496.9   Yes
# 6482           Electronic check          101.45       101.45   Yes
# 5248           Electronic check           20.05       264.55    No
# 3714  Bank transfer (automatic)           59.75       4069.9    No
# 1233  Bank transfer (automatic)           24.70       1685.9    No

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
pd.to_numeric(df.TotalCharges)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-06ba430a4ba5> in <cell line: 1>()
# ----> 1 pd.to_numeric(df.TotalCharges)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     183         coerce_numeric = errors not in ("ignore", "raise")
#     184         try:
# --> 185             values, _ = lib.maybe_convert_numeric(
#     186                 values, set(), coerce_numeric=coerce_numeric
#     187             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " " at position 488

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.iloc[488]
# Out:
# gender                                 Female
# SeniorCitizen                               0
# Partner                                   Yes
# Dependents                                Yes
# tenure                                      0
# PhoneService                               No
# MultipleLines                No phone service
# InternetService                           DSL
# OnlineSecurity                            Yes
# OnlineBackup                               No
# DeviceProtection                          Yes
# TechSupport                               Yes
# StreamingTV                               Yes
# StreamingMovies                            No
# Contract                             Two year
# PaperlessBilling                          Yes
# PaymentMethod       Bank transfer (automatic)
# MonthlyCharges                          52.55
# TotalCharges
# Churn                                      No
# Name: 488, dtype: object

# %%
df[df.TotalCharges!=' '].shape
# Out:
# (7032, 20)

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %% [markdown]
# df[df.TotalCharges!=' '].shape

# %%
df1 = df[df.TotalCharges!=' ']
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df1.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)
# Out:
# <ipython-input-22-b67e0c3d31a6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df1.TotalCharges.dtype
# Out:
# dtype('float64')

# %%
df1[df1.Churn=='No'].tenure
# Out:
# 0        1
# 1       34
# 3       45
# 6       22
# 7       10
#         ..
# 7037    72
# 7038    24
# 7039    72
# 7040    11
# 7042    66
# Name: tenure, Length: 5163, dtype: int64

# %%
tenure_churn_no = df1[df1.Churn=='No'].tenure
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure

plt.xlabel("tenure")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")
plt.hist([tenure_churn_yes, tenure_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
mc_churn_no = df1[df1.Churn=='No'].MonthlyCharges
mc_churn_yes = df1[df1.Churn=='Yes'].MonthlyCharges

plt.xlabel("Monthly Charges")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")



plt.hist([mc_churn_yes, mc_churn_no], rwidth=0.95, color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
def print_unique_col_values(df):
       for column in df:
            if df[column].dtypes=='object':
                print(f'{column}: {df[column].unique()}')

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
df1.replace('No internet service','No',inplace=True)
df1.replace('No phone service','No',inplace=True)
# Out:
# <ipython-input-29-104b877f3854>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service','No',inplace=True)
# <ipython-input-29-104b877f3854>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service','No',inplace=True)

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes': 1,'No': 0},inplace=True)
# Out:
# <ipython-input-31-34dfac0bf179>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({'Yes': 1,'No': 0},inplace=True)

# %% [markdown]
# for col in df1:
#     print(f'{col}: {df1[col].unique()}')

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)
# Out:
# <ipython-input-32-ba153b6b6960>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df1.gender.unique()
# Out:
# array([1, 0])

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 6960       1              1        1           0      42             1
# 2222       0              0        1           1      38             1
# 3996       0              0        0           0      24             1
# 151        0              0        0           0       7             1
# 7002       1              0        1           0      64             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 6960              1               0             1                 1  ...
# 2222              1               0             0                 1  ...
# 3996              0               0             0                 0  ...
# 151               1               0             0                 0  ...
# 7002              1               0             1                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 6960                    0                            1                   0
# 2222                    0                            1                   0
# 3996                    0                            0                   1
# 151                     0                            1                   0
# 7002                    0                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 6960                        1                  0                  0
# 2222                        1                  0                  0
# 3996                        0                  0                  1
# 151                         1                  0                  0
# 7002                        0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 6960                                        0
# 2222                                        0
# 3996                                        0
# 151                                         0
# 7002                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 6960                                      0                               1
# 2222                                      1                               0
# 3996                                      0                               0
# 151                                       0                               0
# 7002                                      0                               0
#
#       PaymentMethod_Mailed check
# 6960                           0
# 2222                           0
# 3996                           1
# 151                            1
# 7002                           0
#
# [5 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %%
X = df2.drop('Churn',axis='columns')
y = df2['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (5625, 26)

# %%
X_test.shape
# Out:
# (1407, 26)

# %%
X_train[:10]
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 5664       1              1        0           0  0.126761             1
# 101        1              0        1           1  0.000000             1
# 2621       0              0        1           0  0.985915             1
# 392        1              1        0           0  0.014085             1
# 1327       0              0        1           0  0.816901             1
# 3607       1              0        0           0  0.169014             1
# 2773       0              0        1           0  0.323944             0
# 1936       1              0        1           0  0.704225             1
# 5387       0              0        0           0  0.042254             0
# 4331       0              0        0           0  0.985915             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 5664              0               0             0                 1  ...
# 101               0               0             0                 0  ...
# 2621              0               0             1                 1  ...
# 392               0               0             0                 0  ...
# 1327              1               0             0                 1  ...
# 3607              0               1             0                 0  ...
# 2773              0               0             0                 1  ...
# 1936              0               1             1                 0  ...
# 5387              0               0             0                 0  ...
# 4331              1               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 5664                    0                            1                   0
# 101                     0                            0                   1
# 2621                    1                            0                   0
# 392                     1                            0                   0
# 1327                    0                            1                   0
# 3607                    1                            0                   0
# 2773                    1                            0                   0
# 1936                    1                            0                   0
# 5387                    1                            0                   0
# 4331                    0                            0                   1
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 5664                        1                  0                  0
# 101                         1                  0                  0
# 2621                        0                  0                  1
# 392                         1                  0                  0
# 1327                        0                  1                  0
# 3607                        0                  1                  0
# 2773                        1                  0                  0
# 1936                        0                  1                  0
# 5387                        1                  0                  0
# 4331                        0                  0                  1
#
#       PaymentMethod_Bank transfer (automatic)  \
# 5664                                        0
# 101                                         0
# 2621                                        0
# 392                                         0
# 1327                                        1
# 3607                                        0
# 2773                                        0
# 1936                                        1
# 5387                                        0
# 4331                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 5664                                      1                               0
# 101                                       0                               1
# 2621                                      1                               0
# 392                                       0                               1
# 1327                                      0                               0
# 3607                                      0                               0
# 2773                                      0                               1
# 1936                                      0                               0
# 5387                                      0                               1
# 4331                                      0                               0
#
#       PaymentMethod_Mailed check
# 5664                           0
# 101                            0
# 2621                           0
# 392                            0
# 1327                           0
# 3607                           1
# 2773                           0
# 1936                           0
# 5387                           0
# 4331                           0
#
# [10 rows x 26 columns]

# %%
len(X_train.columns)
# Out:
# 26

# %%
import tensorflow as tf
from tensorflow import keras


model = keras.Sequential([
    keras.layers.Dense(26, input_shape=(26,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=150)
# Out:
# Epoch 1/150
# 176/176 [==============================] - 1s 2ms/step - loss: 0.4817 - accuracy: 0.7604
# Epoch 2/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4274 - accuracy: 0.7954
# Epoch 3/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4190 - accuracy: 0.8027
# Epoch 4/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4142 - accuracy: 0.8064
# Epoch 5/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4113 - accuracy: 0.8034
# Epoch 6/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4099 - accuracy: 0.8059
# Epoch 7/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4062 - accuracy: 0.8071
# Epoch 8/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4057 - accuracy: 0.8108
# Epoch 9/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4051 - accuracy: 0.8080
# Epoch 10/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4026 - accuracy: 0.8082
# Epoch 11/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.4019 - accuracy: 0.8098
# Epoch 12/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.4001 - accuracy: 0.8101
# Epoch 13/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3998 - accuracy: 0.8114
# Epoch 14/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3992 - accuracy: 0.8149
# Epoch 15/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3984 - accuracy: 0.8137
# Epoch 16/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3967 - accuracy: 0.8108
# Epoch 17/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3955 - accuracy: 0.8162
# Epoch 18/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3946 - accuracy: 0.8155
# Epoch 19/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3938 - accuracy: 0.8162
# Epoch 20/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3928 - accuracy: 0.8146
# Epoch 21/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3915 - accuracy: 0.8144
# Epoch 22/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3902 - accuracy: 0.8160
# Epoch 23/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3911 - accuracy: 0.8171
# Epoch 24/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3896 - accuracy: 0.8137
# Epoch 25/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3892 - accuracy: 0.8165
# Epoch 26/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3885 - accuracy: 0.8153
# Epoch 27/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3867 - accuracy: 0.8156
# Epoch 28/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3862 - accuracy: 0.8176
# Epoch 29/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3845 - accuracy: 0.8169
# Epoch 30/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3853 - accuracy: 0.8160
# Epoch 31/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3840 - accuracy: 0.8201
# Epoch 32/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3838 - accuracy: 0.8176
# Epoch 33/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3824 - accuracy: 0.8196
# Epoch 34/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3825 - accuracy: 0.8226
# Epoch 35/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8199
# Epoch 36/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3812 - accuracy: 0.8219
# Epoch 37/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3791 - accuracy: 0.8229
# Epoch 38/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3780 - accuracy: 0.8226
# Epoch 39/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3767 - accuracy: 0.8261
# Epoch 40/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3776 - accuracy: 0.8208
# Epoch 41/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3773 - accuracy: 0.8215
# Epoch 42/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3754 - accuracy: 0.8224
# Epoch 43/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3748 - accuracy: 0.8247
# Epoch 44/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3737 - accuracy: 0.8236
# Epoch 45/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3724 - accuracy: 0.8235
# Epoch 46/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3721 - accuracy: 0.8240
# Epoch 47/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3725 - accuracy: 0.8226
# Epoch 48/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3712 - accuracy: 0.8236
# Epoch 49/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3706 - accuracy: 0.8236
# Epoch 50/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3689 - accuracy: 0.8215
# Epoch 51/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3723 - accuracy: 0.8260
# Epoch 52/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3686 - accuracy: 0.8274
# Epoch 53/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3674 - accuracy: 0.8254
# Epoch 54/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3667 - accuracy: 0.8281
# Epoch 55/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3657 - accuracy: 0.8272
# Epoch 56/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3662 - accuracy: 0.8270
# Epoch 57/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3646 - accuracy: 0.8295
# Epoch 58/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3648 - accuracy: 0.8265
# Epoch 59/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3631 - accuracy: 0.8295
# Epoch 60/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3634 - accuracy: 0.8288
# Epoch 61/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3637 - accuracy: 0.8288
# Epoch 62/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3623 - accuracy: 0.8277
# Epoch 63/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3608 - accuracy: 0.8295
# Epoch 64/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3622 - accuracy: 0.8292
# Epoch 65/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3603 - accuracy: 0.8306
# Epoch 66/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3597 - accuracy: 0.8292
# Epoch 67/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3593 - accuracy: 0.8293
# Epoch 68/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3589 - accuracy: 0.8292
# Epoch 69/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3584 - accuracy: 0.8290
# Epoch 70/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3580 - accuracy: 0.8279
# Epoch 71/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3558 - accuracy: 0.8329
# Epoch 72/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3552 - accuracy: 0.8313
# Epoch 73/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3571 - accuracy: 0.8299
# Epoch 74/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3564 - accuracy: 0.8341
# Epoch 75/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3548 - accuracy: 0.8309
# Epoch 76/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3553 - accuracy: 0.8313
# Epoch 77/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3540 - accuracy: 0.8347
# Epoch 78/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3535 - accuracy: 0.8336
# Epoch 79/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3523 - accuracy: 0.8318
# Epoch 80/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3533 - accuracy: 0.8336
# Epoch 81/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3526 - accuracy: 0.8347
# Epoch 82/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3514 - accuracy: 0.8359
# Epoch 83/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3498 - accuracy: 0.8366
# Epoch 84/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3506 - accuracy: 0.8338
# Epoch 85/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3493 - accuracy: 0.8347
# Epoch 86/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3501 - accuracy: 0.8352
# Epoch 87/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3500 - accuracy: 0.8329
# Epoch 88/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3486 - accuracy: 0.8363
# Epoch 89/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3484 - accuracy: 0.8370
# Epoch 90/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3475 - accuracy: 0.8352
# Epoch 91/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3467 - accuracy: 0.8379
# Epoch 92/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3475 - accuracy: 0.8366
# Epoch 93/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3454 - accuracy: 0.8375
# Epoch 94/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3459 - accuracy: 0.8377
# Epoch 95/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3464 - accuracy: 0.8388
# Epoch 96/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3456 - accuracy: 0.8380
# Epoch 97/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3447 - accuracy: 0.8379
# Epoch 98/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3438 - accuracy: 0.8364
# Epoch 99/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3435 - accuracy: 0.8372
# Epoch 100/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3422 - accuracy: 0.8386
# Epoch 101/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3411 - accuracy: 0.8373
# Epoch 102/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3418 - accuracy: 0.8388
# Epoch 103/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3418 - accuracy: 0.8372
# Epoch 104/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3394 - accuracy: 0.8386
# Epoch 105/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3412 - accuracy: 0.8384
# Epoch 106/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3401 - accuracy: 0.8356
# Epoch 107/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3396 - accuracy: 0.8400
# Epoch 108/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3389 - accuracy: 0.8391
# Epoch 109/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3380 - accuracy: 0.8382
# Epoch 110/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3395 - accuracy: 0.8382
# Epoch 111/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3379 - accuracy: 0.8400
# Epoch 112/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3382 - accuracy: 0.8396
# Epoch 113/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3379 - accuracy: 0.8382
# Epoch 114/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3374 - accuracy: 0.8411
# Epoch 115/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3367 - accuracy: 0.8427
# Epoch 116/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3369 - accuracy: 0.8427
# Epoch 117/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3353 - accuracy: 0.8436
# Epoch 118/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3369 - accuracy: 0.8421
# Epoch 119/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3357 - accuracy: 0.8395
# Epoch 120/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8412
# Epoch 121/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3342 - accuracy: 0.8412
# Epoch 122/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3332 - accuracy: 0.8414
# Epoch 123/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3341 - accuracy: 0.8405
# Epoch 124/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3324 - accuracy: 0.8443
# Epoch 125/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3324 - accuracy: 0.8421
# Epoch 126/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3336 - accuracy: 0.8425
# Epoch 127/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3325 - accuracy: 0.8430
# Epoch 128/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3326 - accuracy: 0.8409
# Epoch 129/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3318 - accuracy: 0.8441
# Epoch 130/150
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3314 - accuracy: 0.8437
# Epoch 131/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3323 - accuracy: 0.8416
# Epoch 132/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3295 - accuracy: 0.8405
# Epoch 133/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3304 - accuracy: 0.8432
# Epoch 134/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3307 - accuracy: 0.8434
# Epoch 135/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3310 - accuracy: 0.8412
# Epoch 136/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3294 - accuracy: 0.8411
# Epoch 137/150
# 176/176 [==============================] - 0s 3ms/step - loss: 0.3293 - accuracy: 0.8421
# Epoch 138/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3288 - accuracy: 0.8441
# Epoch 139/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3300 - accuracy: 0.8405
# Epoch 140/150
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3290 - accuracy: 0.8411
# Epoch 141/150
# 176/176 [==============================] - 1s 6ms/step - loss: 0.3284 - accuracy: 0.8434
# Epoch 142/150
# 176/176 [==============================] - 1s 5ms/step - loss: 0.3304 - accuracy: 0.8441
# Epoch 143/150
# 176/176 [==============================] - 1s 3ms/step - loss: 0.3266 - accuracy: 0.8450
# Epoch 144/150
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3265 - accuracy: 0.8432
# Epoch 145/150
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3273 - accuracy: 0.8457
# Epoch 146/150
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3264 - accuracy: 0.8443
# Epoch 147/150
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3268 - accuracy: 0.8466
# Epoch 148/150
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3267 - accuracy: 0.8475
# Epoch 149/150
# 176/176 [==============================] - 1s 4ms/step - loss: 0.3275 - accuracy: 0.8428
# Epoch 150/150
# 176/176 [==============================] - 1s 5ms/step - loss: 0.3276 - accuracy: 0.8446

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 0s 2ms/step - loss: 0.5616 - accuracy: 0.7527
# [0.561629056930542, 0.7526652216911316]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# 44/44 [==============================] - 0s 2ms/step
# array([[0.50801677],
#        [0.60378164],
#        [0.00405829],
#        [0.8641362 ],
#        [0.12035389]], dtype=float32)

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [1, 1, 0, 1, 0, 1, 0, 0, 0, 0]

# %%
y_test[:10]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# 816     1
# 2670    0
# 5920    0
# 1023    0
# 6087    0
# Name: Churn, dtype: int64

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83       999
#            1       0.60      0.45      0.52       408
#
#     accuracy                           0.75      1407
#    macro avg       0.70      0.66      0.67      1407
# weighted avg       0.74      0.75      0.74      1407

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
round((862+229)/(862+229+137+179),2)
# Out:
# 0.78
